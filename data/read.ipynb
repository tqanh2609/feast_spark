# %%
import pandas as pd

# %%
table = pd.read_parquet('F:/feature_store/my_project/feature_repo/data/driver_stats.parquet')

# %%
table
# Out:
#                event_timestamp  driver_id  conv_rate  acc_rate  \
# 0    2025-04-08 16:00:00+00:00       1005   0.963286  0.346438
# 1    2025-04-08 17:00:00+00:00       1005   0.784096  0.826455
# 2    2025-04-08 18:00:00+00:00       1005   0.864776  0.694390
# 3    2025-04-08 19:00:00+00:00       1005   0.032158  0.126072
# 4    2025-04-08 20:00:00+00:00       1005   0.416596  0.481476
# ...                        ...        ...        ...       ...
# 1802 2025-04-23 14:00:00+00:00       1001   0.404808  0.891893
# 1803 2025-04-23 15:00:00+00:00       1001   0.550128  0.608453
# 1804 2021-04-12 07:00:00+00:00       1001   0.031889  0.659691
# 1805 2025-04-16 04:00:00+00:00       1003   0.044004  0.369231
# 1806 2025-04-16 04:00:00+00:00       1003   0.044004  0.369231
#
#       avg_daily_trips                 created
# 0                 169 2025-04-23 16:49:56.519
# 1                 299 2025-04-23 16:49:56.519
# 2                 922 2025-04-23 16:49:56.519
# ...

# %%
table.dtypes
# Out:
# event_timestamp    datetime64[ns, UTC]
# driver_id                        int64
# conv_rate                      float32
# acc_rate                       float32
# avg_daily_trips                  int32
# created                 datetime64[us]
# dtype: object
